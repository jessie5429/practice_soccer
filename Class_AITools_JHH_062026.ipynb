# %% [markdown]
# <a href="https://colab.research.google.com/github/jessie5429/practice_soccer/blob/main/Class_AITools_JHH_062026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system( "git clone https://github.com/erikwestlund/ai-tools-2026.git")

# %%
setwd("ai-tools-2026")

# %%
source("updater.R")
# Out:
# Updating instructor-owned course files with git pull --ff-only...
#
# Files in practice/work/ are left alone by Git and by this script unless a file is missing.
#
# Already up to date.
#
# Practice task seeding complete.
#
# Copied new files: 22
#
# Skipped existing files: 0
#
#
# New files copied to practice/work/:
#
# - 00_open-project-and-glimpse/_quarto.yml
# - 00_open-project-and-glimpse/data/codebook.md
# - 00_open-project-and-glimpse/data/project_check.csv
# - 00_open-project-and-glimpse/open-project-and-glimpse.code-workspace
# - 00_open-project-and-glimpse/open-project-and-glimpse.Rproj
# - 00_open-project-and-glimpse/starter-notebook.qmd
# - 01_clean-and-visualize/_quarto.yml
# - 01_clean-and-visualize/01_data-cleaning.qmd
# - 01_clean-and-visualize/02_data-summary.qmd
# - 01_clean-and-visualize/03_data-analysis.qmd
# - 01_clean-and-visualize/clean-and-visualize.code-workspace
# - 01_clean-and-visualize/clean-and-visualize.Rproj
# - 01_clean-and-visualize/data/codebook.md
# ...
